# %%
import os
import joblib #for saving UMAP model

#Requires:
#scikit-learn, umap, joblib
#for old format, you need: (open from Python version 3.12.4, conda 24.7.1, joblib 1.4.2)
#for new format: (open from Python 3.9.13, clustering5, joblib 1.4.2)

#Script

#Old format 
# trial_folder = r"E:\Feb-March_2024_zircon imaging\05_zircon geochemical data\carrasco-godoy data\Elises code for marco\V3_zirconfertility\outputs\V3_zirconfertility_PCA"
trial_folder = r"E:\Feb-March_2024_zircon imaging\05_zircon geochemical data\carrasco-godoy data\Elises code for marco\v3_zircongeochemistry\outputs\V3_zircongeochemistry_pca"
filepath1 = os.path.join(trial_folder, 'standard_scaler.xml')
filepath2 = os.path.join(trial_folder, 'umap_model.xml')

# #New format 
# trial_folder = r"E:\Feb-March_2024_zircon imaging\05_zircon geochemical data\carrasco-godoy data\UMAP_trials\global_geochemistry_trial2"
# filepath1 = os.path.join(trial_folder, 'standard_scaler.sav')
# filepath2 = os.path.join(trial_folder, 'umap_model.sav')

sc = joblib.load(filepath1) #scaler
umap_model = joblib.load(filepath2) #umap transformation

print(umap_model)
# embedding2 = umap_model.embedding_
# Out:
# e:\Feb-March_2024_zircon imaging\05_zircon geochemical data\carrasco-godoy data\EliseEnv\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.4.2 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# UMAP(angular_rp_forest=True, metric='correlation', min_dist=0.003, n_neighbors=20, tqdm_kwds={'bar_format': '{desc}: {percentage:3.0f}%| {bar} {n_fmt}/{total_fmt} [{elapsed}]', 'desc': 'Epochs completed', 'disable': True})
